# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Jaseem.csv')

# %%
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df1 = df.dropna()

# %%
df1.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
df1.mean()
# Out:
# C:\Users\91960\AppData\Local\Temp\ipykernel_20364\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# anime_id    13638.001165
# rating          6.478264
# members     18348.879005
# dtype: float64

# %%
df1.median()
# Out:
# C:\Users\91960\AppData\Local\Temp\ipykernel_20364\2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# anime_id    9959.00
# rating         6.57
# members     1552.00
# dtype: float64

# %%
df1.mode()
# Out:
#        anime_id                     name   genre type episodes  rating  \
# 0             1         Saru Kani Gassen  Hentai   TV        1     6.0
# 1             5  Shi Wan Ge Leng Xiaohua     NaN  NaN      NaN     NaN
# 2             6                      NaN     NaN  NaN      NaN     NaN
# 3             7                      NaN     NaN  NaN      NaN     NaN
# 4             8                      NaN     NaN  NaN      NaN     NaN
# ...         ...                      ...     ...  ...      ...     ...
# 12012     34476                      NaN     NaN  NaN      NaN     NaN
# 12013     34490                      NaN     NaN  NaN      NaN     NaN
# 12014     34503                      NaN     NaN  NaN      NaN     NaN
# 12015     34514                      NaN     NaN  NaN      NaN     NaN
# 12016     34519                      NaN     NaN  NaN      NaN     NaN
#
#        members
# 0         60.0
# 1         72.0
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# ...

# %%
df.type.value_counts()
# Out:
# TV         3787
# OVA        3311
# Movie      2348
# Special    1676
# ONA         659
# Music       488
# Name: type, dtype: int64

# %%
df['genre'].value_counts()
# Out:
# Hentai                                                  823
# Comedy                                                  523
# Music                                                   301
# Kids                                                    199
# Comedy, Slice of Life                                   179
#                                                        ...
# Adventure, Drama, Fantasy, Game, Sci-Fi                   1
# Adventure, Demons, Fantasy, Historical                    1
# Action, Comedy, Drama, Mecha, Music, Sci-Fi, Shounen      1
# Action, Comedy, Fantasy, Mecha, Sci-Fi, Shounen           1
# Hentai, Slice of Life                                     1
# Name: genre, Length: 3264, dtype: int64

# %%
df['genre'].value_counts(normalize=True)
# Out:
# Hentai                                                  0.067283
# Comedy                                                  0.042757
# Music                                                   0.024608
# Kids                                                    0.016269
# Comedy, Slice of Life                                   0.014634
#                                                           ...
# Adventure, Drama, Fantasy, Game, Sci-Fi                 0.000082
# Adventure, Demons, Fantasy, Historical                  0.000082
# Action, Comedy, Drama, Mecha, Music, Sci-Fi, Shounen    0.000082
# Action, Comedy, Fantasy, Mecha, Sci-Fi, Shounen         0.000082
# Hentai, Slice of Life                                   0.000082
# Name: genre, Length: 3264, dtype: float64

# %%
pd.crosstab(df['genre'],df.type)
# Out:
# type                                                Movie  Music  ONA  OVA  \
# genre
# Action                                                 18      0   13   11
# Action, Adventure                                       4      0    1    3
# Action, Adventure, Cars, Comedy, Sci-Fi, Shounen        1      0    0    1
# Action, Adventure, Cars, Mecha, Sci-Fi, Shounen...      0      0    0    0
# Action, Adventure, Cars, Sci-Fi                         1      0    0    0
# ...                                                   ...    ...  ...  ...
# Super Power, Supernatural, Vampire                      0      0    0    1
# Supernatural                                            9      0    1    0
# Thriller                                                0      0    0    0
# Vampire                                                 0      0    0    0
# Yaoi                                                    0      0    0    2
#
# ...

# %%
df.rating.plot.hist()
plt.show()

# %%
sns.boxplot(df.rating)
plt.show()
# Out:
# C:\Users\91960\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(df.rating,df.members)
plt.show()

# %%
correlation=df1.corr()
correlation
# Out:
#           anime_id    rating   members
# anime_id  1.000000 -0.280954 -0.073964
# rating   -0.280954  1.000000  0.388499
# members  -0.073964  0.388499  1.000000

# %%
plt.subplots(figsize=(28,8))
sns.heatmap(correlation,annot=True,
           xticklabels = correlation.columns.values,
           yticklabels = correlation.columns.values);
plt.show()

# %%
sns.pairplot(data=df1,vars=["genre","type","episodes"])
plt.show()
# Out:
# C:\Users\91960\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(df[["genre","type","episodes","rating","members","anime_id"]].corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
df.groupby("type")["members"].aggregate(["mean","median"]).plot.bar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
